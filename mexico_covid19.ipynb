# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import sklearn as sk

# %% [markdown]
# # read the csv file

# %%
data1 = pd.read_csv("mexico_covid19.csv")

# %%
print(data1)
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
# ...

# %% [markdown]
# # Total NAN value in the entire dataframe

# %%
df.isna().sum().sum()
# Out:
# 6

# %% [markdown]
# # Replace inf by nan value

# %%
inf_replace = df.replace(-np.inf, np.nan)

# %%
drop_nan = df.dropna(inplace = True)

# %%
df
# Out:
#              id FECHA_ARCHIVO ID_REGISTRO  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  \
# 0          9269    2020-04-12      00011f          25           25          2
# 1         33333    2020-04-12      00014e          14           14          2
# 2         35483    2020-04-12      000153           8            8          1
# 3          7062    2020-04-12      0001b6           9           15          1
# 4         23745    2020-04-12      0001c1           9            9          2
# ...         ...           ...         ...         ...          ...        ...
# 263002  7094887    2020-06-03      1e019c          32           32          1
# 263003  7053721    2020-06-03      1e2b05          12           12          1
# 263004  7055429    2020-06-03      1e473f          20           20          1
# 263005  7043768    2020-06-03      1e6da1          13           13          1
# 263006  7093277    2020-06-03      1e8453           9            9          1
#
# ...

# %% [markdown]
# # 	Droping multiple specific Columns

# %%
df.drop(['FECHA_ARCHIVO','ID_REGISTRO','ENTIDAD','FECHA_ACTUALIZACION','FECHA_INGRESO','FECHA_SINTOMAS'], axis = 1, inplace = True)

# %%
df
# Out:
#              id  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  ENTIDAD_REGISTRO  \
# 0          9269          25           25          2      0                25
# 1         33333          14           14          2      0                14
# 2         35483           8            8          1      0                 8
# 3          7062           9           15          1      0                 9
# 4         23745           9            9          2      0                 9
# ...         ...         ...          ...        ...    ...               ...
# 263002  7094887          32           32          1      0                32
# 263003  7053721          12           12          1      0                12
# 263004  7055429          20           20          1      0                20
# 263005  7043768          13           13          1      0                13
# 263006  7093277           9            9          1      0                 9
#
# ...

# %% [markdown]
# # Droping multiple rows

# %%
df.head()
# Out:
#       id  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  ENTIDAD_REGISTRO ABR_ENT  \
# 0   9269          25           25          2      0                25      SL
# 1  33333          14           14          2      0                14      JC
# 2  35483           8            8          1      0                 8      CH
# 3   7062           9           15          1      0                 9      DF
# 4  23745           9            9          2      0                 9      DF
#
#    ORIGEN  SECTOR  SEXO  ...  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 0       2      12     2  ...         2               2         1
# 1       1       4     1  ...         2               2         1
# 2       1       4     2  ...         2               2         2
# 3       2       4     1  ...         2               2         1
# 4       1       4     1  ...         2               2         2
#
#   RENAL_CRONICA  TABAQUISMO  OTRO_CASO  MIGRANTE  PAIS_NACIONALIDAD  \
# ...

# %%
df.drop([0,3], axis = 0)
# Out:
#              id  ENTIDAD_UM  ENTIDAD_RES  RESULTADO  DELAY  ENTIDAD_REGISTRO  \
# 1         33333          14           14          2      0                14
# 2         35483           8            8          1      0                 8
# 4         23745           9            9          2      0                 9
# 5          5019          19           19          2      0                19
# 6         30173          17           17          2      0                17
# ...         ...         ...          ...        ...    ...               ...
# 263002  7094887          32           32          1      0                32
# 263003  7053721          12           12          1      0                12
# 263004  7055429          20           20          1      0                20
# 263005  7043768          13           13          1      0                13
# 263006  7093277           9            9          1      0                 9
#
# ...

# %% [markdown]
# # Applying Mean, Variance, Count

# %%
df.count()
# Out:
# id                    263001
# ENTIDAD_UM            263001
# ENTIDAD_RES           263001
# RESULTADO             263001
# DELAY                 263001
# ENTIDAD_REGISTRO      263001
# ABR_ENT               263001
# ORIGEN                263001
# SECTOR                263001
# SEXO                  263001
# ENTIDAD_NAC           263001
# MUNICIPIO_RES         263001
# TIPO_PACIENTE         263001
# FECHA_DEF             263001
# INTUBADO              263001
# NEUMONIA              263001
# EDAD                  263001
# NACIONALIDAD          263001
# EMBARAZO              263001
# HABLA_LENGUA_INDIG    263001
# DIABETES              263001
# EPOC                  263001
# ASMA                  263001
# INMUSUPR              263001
# HIPERTENSION          263001
# OTRA_COM              263001
# CARDIOVASCULAR        263001
# OBESIDAD              263001
# RENAL_CRONICA         263001
# TABAQUISMO            263001
# OTRO_CASO             263001
# MIGRANTE              263001
# ...

# %%
df.mean(axis = 1) #donot mention skipna becauce I have already taken care of NAN valus
# Out:
# 0            319.000000
# 1           1090.129032
# 2           1158.612903
# 3            245.000000
# 4            785.225806
#               ...
# 263002    228888.419355
# 263003    227551.354839
# 263004    227619.322581
# 263005    227232.032258
# 263006    228828.258065
# Length: 263001, dtype: float64

# %%
df.var(axis = 1)
# Out:
# 0         2.760205e+06
# 1         3.580947e+07
# 2         4.058205e+07
# 3         1.601730e+06
# 4         1.815869e+07
#               ...
# 263002    1.623778e+12
# 263003    1.604994e+12
# 263004    1.605765e+12
# 263005    1.600467e+12
# 263006    1.623045e+12
# Length: 263001, dtype: float64

# %% [markdown]
# # Violin plot
